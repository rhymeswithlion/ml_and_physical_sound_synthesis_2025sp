# %% [markdown]
# # Commuted Piano Synthesis Experiment

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## hammer-string interaction

# %%
import matplotlib.pyplot as plt
import numpy as np

from audio_utils import impulse

length = 100

x = np.linspace(-1, 10, 100)
strike1 = np.exp(-10 * (1 - np.pow(7, -0.75 - x)) ** 2)
strike1 /= sum(strike1)


x = np.linspace(-1.1, 2.5, 100)
strike2 = np.exp(-10 * (1 - np.pow(7, -0.75 - x)) ** 2)
strike2 /= sum(strike2)

x = np.linspace(-1.15, 0, 100)
strike3 = np.exp(-10 * (1 - np.pow(7, -0.75 - x)) ** 2)
strike3 /= sum(strike3)

strike = strike1 + strike2 + strike3
plt.plot(strike)

# %% [markdown]
# ## all-pass filter for dispersion
#
# This might be backwards, but doing it the other way is causing instability. Check this out later.

# %%
# See https://ccrma.stanford.edu/~jos/Piano/Piano.pdf
# for more information about the all-pass filter


from audio_utils import plot_freqz

ap_denom = np.array([7, 1.0, 6])


plot_freqz(ap_denom[::-1], ap_denom, 44100)

# %% [markdown]
# ## a rich IR for the body

# %%
# download https://oramics.github.io/sampled/IR/EMT140-Plate/samples/emt_140_dark_1.wav to data/

! wget -c https://oramics.github.io/sampled/IR/EMT140-Plate/samples/emt_140_dark_1.wav -O data/emt_140_dark_1.wav

from scipy.io import wavfile

from audio_utils import play_audio

sr, plate = wavfile.read("data/emt_140_dark_1.wav")
plate = plate / (2**31)


def fade_out(x, seconds):
    output = np.zeros_like(x)

    fade = np.linspace(1, 0, seconds * sr)
    if len(fade) > len(x):
        fade = fade[-len(x) :]
    output[-len(fade) :] = x[-len(fade) :] * fade
    return output


plate_left = fade_out(plate[:25000, 0], 1)
plate_right = fade_out(plate[:25000, 1], 1)

play_audio(plate_left, auto_play=True)
# Out:
# --2025-02-19 08:40:34--  https://oramics.github.io/sampled/IR/EMT140-Plate/samples/emt_140_dark_1.wav
# Resolving oramics.github.io (oramics.github.io)... 185.199.111.153, 185.199.108.153, 185.199.109.153, ...
# Connecting to oramics.github.io (oramics.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
# /var/folders/zk/5c2c39w140d2jm1q_p1lzdr00000gn/T/ipykernel_4445/2518699089.py:9: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, plate = wavfile.read("data/emt_140_dark_1.wav")
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## the commuted synthesis model
#
# This is all LTI's, so everything commutes. For simplicity, the hammer-string interaction is constant, but per https://ccrma.stanford.edu/~jos/pdf/svd95.pdf, the force diagram can be used as an easy source of nonlinearity by making it non-linearly dependent on the string velocity.

# %%
import numpy as np
from joblib import Memory
from scipy.signal import convolve

from audio_utils import (
    add_silence,
    biquad_lpf_coeffs,
    comb,
    mfcc_hash,
    play_audio,
    string,
    white_noise,
)

memory = Memory("cache", verbose=0)


def mtof(m):
    return 440 * 2 ** ((m - 69) / 12)


def midi_to_piano_note(m, show_graphs=False, channel="L"):
    b, a = biquad_lpf_coeffs(17000, 0.5, 44100)
    ap_denom = np.array([7, 1, 6])

    res = impulse(0.01)

    res = convolve(res, white_noise(0.05))
    res /= np.max(np.abs(res))
    if show_graphs:
        play_audio(res, title="white_noise", normalize=True)

    for i in range(10):
        res = comb(res, int((5 + i) / 3), 0.95 - 0.03 * i, 0.10)
    res /= np.max(np.abs(res))
    if show_graphs:
        play_audio(res, title="many filters", normalize=True)

    res = convolve(res, strike)
    res /= np.max(np.abs(res))
    if show_graphs:
        play_audio(res, title="strike", normalize=True)

    if channel == "L":
        res = convolve(plate_left, res)
    else:
        res = convolve(plate_right, res)
    res /= np.max(np.abs(res))
    if show_graphs:
        play_audio(res, title="plate", normalize=True)
    res = (
        0.5
        * string(
            add_silence(res, 5),
            int(44100.0 / mtof(m)),
            0.995,
            *b,
            *a,
            *ap_denom[::-1],
            *ap_denom,
        )
        + 0.2
        * string(
            add_silence(res, 5),
            int(44100.0 / mtof(m) * (0.999 if channel == "L" else 0.998)),
            (0.99 if channel == "L" else 0.98),
            *b,
            *a,
            *ap_denom[::-1],
            *ap_denom,
        )
        + 0.1
        * string(
            add_silence(res, 5),
            int(44100.0 / mtof(m) * (0.1 if channel == "L" else 0.11)),
            (0.9 if channel == "L" else 0.91),
            *b,
            *a,
            *ap_denom[::-1],
            *ap_denom,
        )
    )
    res /= np.max(np.abs(res))
    if show_graphs:
        play_audio(res, title="string", normalize=True)

    print(mfcc_hash(res)[:3])

    if show_graphs:
        play_audio(res, auto_play=True, normalize=True, title="final")

    res /= np.max(np.abs(res))
    return res * 0.95  # avoid clipping


midi_to_piano_note(59, show_graphs=True)


midi_to_piano_note = memory.cache(midi_to_piano_note)
# Out:
# white_noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# many filters
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# strike
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# plate
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# string
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ['silly-peak', 'stable-cove', 'coherent-reuben']
# final
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## write this out to wave files and render some piano piece
#
# Something in the implementation is affecting the tuning. Look into this some more.

# %%
# write as wav files
for m in range(12, 96):
    waves = np.array(
        [midi_to_piano_note(m, channel=channel) for channel in ["L", "R"]]
    ).T
    wavfile.write(f"data/piano_{m}.wav", 44100, (waves * 2**15).astype(np.int16))

# %%
! wget -c "https://bitmidi.com/uploads/30381.mid" -O data/mozart_k545.mid
# Out:
# --2025-02-19 08:40:37--  https://bitmidi.com/uploads/30381.mid
# Resolving bitmidi.com (bitmidi.com)... 104.21.66.148, 172.67.205.51, 2606:4700:3033::ac43:cd33, ...
# Connecting to bitmidi.com (bitmidi.com)|104.21.66.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [audio/midi]
# Saving to: ‘data/mozart_k545.mid’
#
# data/mozart_k545.mi     [ <=>                ]  33.23K  --.-KB/s    in 0.04s
#
# 2025-02-19 08:40:37 (849 KB/s) - ‘data/mozart_k545.mid’ saved [34025]

# %%
from pydub import AudioSegment

(
    AudioSegment.from_wav(f"data/piano_{84}.wav")
    .apply_gain(-18)
    .get_sample_slice(np.random.randint(0, 30), int(1000 / 1000 * sr))
    .fade_out(100)
    .fade_in(30)
)
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
from collections import defaultdict

from mido import MidiFile
from pydub import AudioSegment

mid = MidiFile("./data/mozart_k545.mid")
total_duration = 60 * 1000.0
output = AudioSegment.silent(total_duration)

tempo = 110  # bpm


def ticks_to_ms(ticks):
    tick_ms = (60000.0 / tempo) / mid.ticks_per_beat
    return ticks * tick_ms


sr = 44100
for track in mid.tracks:
    if "piano" not in track.name.lower() and len(mid.tracks) > 3:
        print(f"skipping {track.name}")
        continue
    print(f"Track {track.name}")

    current_pos = 0.0

    current_notes = defaultdict(dict)
    audio_segments = {}

    for msg in track:
        current_pos += ticks_to_ms(msg.time)
        if current_pos > total_duration:
            break

        if msg.type == "note_on" and msg.velocity > 0:
            current_notes[msg.channel][msg.note] = (current_pos, msg)

        if msg.type == "note_on" and msg.velocity == 0:
            if msg.note not in current_notes[msg.channel]:
                continue
            start_pos, start_msg = current_notes[msg.channel].pop(msg.note)
            print(
                f"rendering note {msg.note} at {current_pos} with velocity {start_msg.velocity}"
            )

            duration = current_pos - start_pos

            filename = f"data/piano_{msg.note}.wav"

            if filename not in audio_segments:
                audio_segments[msg.note] = AudioSegment.from_wav(filename)

            rendered = (
                audio_segments[msg.note]
                .apply_gain(-24)
                .apply_gain(20 * np.log10(start_msg.velocity / 127))
            )

            if msg.note < 84:
                rendered = rendered.get_sample_slice(
                    np.random.randint(0, 20),
                    max(int(duration / 1000.0 * 1.5 * sr), 700),
                )
            rendered = rendered.fade_out(100)

            output = output.overlay(rendered, start_pos)

output
# Out:
# Track
# Track Mozart: Sonata Facile KV545
# rendering note 60 at 272.72727272727275 with velocity 96
# rendering note 67 at 545.4545454545455 with velocity 96
# rendering note 64 at 818.1818181818182 with velocity 96
# rendering note 67 at 1090.909090909091 with velocity 96
# rendering note 72 at 1090.909090909091 with velocity 96
# rendering note 60 at 1363.6363636363637 with velocity 96
# rendering note 67 at 1636.3636363636365 with velocity 96
# rendering note 76 at 1636.3636363636365 with velocity 96
# rendering note 64 at 1909.0909090909092 with velocity 96
# rendering note 67 at 2181.818181818182 with velocity 96
# rendering note 79 at 2181.818181818182 with velocity 96
# rendering note 62 at 2454.545454545455 with velocity 96
# rendering note 67 at 2727.272727272728 with velocity 96
# rendering note 65 at 3000.000000000001 with velocity 96
# rendering note 71 at 3000.000000000001 with velocity 96
# rendering note 72 at 3136.3636363636374 with velocity 96
# rendering note 74 at 3272.727272727274 with velocity 96
# rendering note 67 at 3272.727272727274 with velocity 96
# rendering note 60 at 3545.454545454547 with velocity 96
# rendering note 67 at 3818.18181818182 with velocity 96
# rendering note 64 at 4090.909090909093 with velocity 96
# rendering note 67 at 4363.636363636366 with velocity 96
# rendering note 72 at 4363.636363636366 with velocity 96
# rendering note 60 at 4636.363636363639 with velocity 96
# rendering note 69 at 4909.090909090912 with velocity 96
# rendering note 65 at 5181.818181818185 with velocity 96
# rendering note 69 at 5454.545454545458 with velocity 96
# rendering note 81 at 5454.545454545458 with velocity 96
# rendering note 60 at 5727.272727272731 with velocity 96
# rendering note 67 at 6000.000000000004 with velocity 96
# rendering note 79 at 6000.000000000004 with velocity 96
# rendering note 64 at 6272.727272727277 with velocity 96
# rendering note 67 at 6545.45454545455 with velocity 96
# rendering note 84 at 6545.45454545455 with velocity 96
# rendering note 59 at 6818.181818181823 with velocity 96
# rendering note 67 at 7090.9090909090955 with velocity 96
# rendering note 79 at 7090.9090909090955 with velocity 96
# rendering note 77 at 7179.5454545454595 with velocity 96
# rendering note 79 at 7270.4545454545505 with velocity 96
# rendering note 77 at 7361.3636363636415 with velocity 96
# rendering note 62 at 7363.6363636363685 with velocity 96
# rendering note 76 at 7500.000000000005 with velocity 96
# rendering note 77 at 7636.363636363641 with velocity 96
# rendering note 67 at 7636.363636363641 with velocity 96
# rendering note 60 at 7909.090909090914 with velocity 96
# rendering note 67 at 8181.8181818181865 with velocity 96
# rendering note 76 at 8181.8181818181865 with velocity 96
# rendering note 64 at 8454.54545454546 with velocity 96
# rendering note 67 at 8727.272727272732 with velocity 96
# rendering note 69 at 9000.000000000004 with velocity 96
# rendering note 71 at 9136.36363636364 with velocity 96
# rendering note 72 at 9272.727272727276 with velocity 96
# rendering note 65 at 9272.727272727276 with velocity 96
# rendering note 74 at 9409.090909090912 with velocity 96
# rendering note 76 at 9545.454545454548 with velocity 96
# rendering note 77 at 9681.818181818184 with velocity 96
# rendering note 79 at 9818.18181818182 with velocity 96
# rendering note 81 at 9954.545454545456 with velocity 96
# rendering note 79 at 10090.909090909092 with velocity 96
# rendering note 77 at 10227.272727272728 with velocity 96
# rendering note 76 at 10363.636363636364 with velocity 96
# rendering note 74 at 10500.0 with velocity 96
# rendering note 72 at 10636.363636363636 with velocity 96
# rendering note 71 at 10772.727272727272 with velocity 96
# rendering note 69 at 10909.090909090908 with velocity 96
# rendering note 60 at 10909.090909090908 with velocity 96
# rendering note 53 at 10909.090909090908 with velocity 96
# rendering note 67 at 11181.81818181818 with velocity 96
# rendering note 69 at 11318.181818181816 with velocity 96
# rendering note 71 at 11454.545454545452 with velocity 96
# rendering note 60 at 11454.545454545452 with velocity 96
# rendering note 52 at 11454.545454545452 with velocity 96
# rendering note 72 at 11590.909090909088 with velocity 96
# rendering note 74 at 11727.272727272724 with velocity 96
# rendering note 76 at 11863.63636363636 with velocity 96
# rendering note 77 at 11999.999999999996 with velocity 96
# rendering note 79 at 12136.363636363632 with velocity 96
# rendering note 77 at 12272.727272727268 with velocity 96
# rendering note 76 at 12409.090909090904 with velocity 96
# rendering note 74 at 12545.45454545454 with velocity 96
# rendering note 72 at 12681.818181818177 with velocity 96
# rendering note 71 at 12818.181818181813 with velocity 96
# rendering note 69 at 12954.545454545449 with velocity 96
# rendering note 67 at 13090.909090909085 with velocity 96
# rendering note 60 at 13090.909090909085 with velocity 96
# rendering note 52 at 13090.909090909085 with velocity 96
# rendering note 65 at 13363.636363636357 with velocity 96
# rendering note 67 at 13499.999999999993 with velocity 96
# rendering note 69 at 13636.363636363629 with velocity 96
# rendering note 60 at 13636.363636363629 with velocity 96
# rendering note 50 at 13636.363636363629 with velocity 96
# rendering note 71 at 13772.727272727265 with velocity 96
# rendering note 72 at 13909.0909090909 with velocity 96
# rendering note 74 at 14045.454545454537 with velocity 96
# rendering note 76 at 14181.818181818173 with velocity 96
# rendering note 77 at 14318.181818181809 with velocity 96
# rendering note 76 at 14454.545454545445 with velocity 96
# rendering note 74 at 14590.909090909081 with velocity 96
# rendering note 72 at 14727.272727272717 with velocity 96
# rendering note 71 at 14863.636363636353 with velocity 96
# rendering note 69 at 14999.999999999989 with velocity 96
# rendering note 67 at 15136.363636363625 with velocity 96
# rendering note 65 at 15272.727272727261 with velocity 96
# rendering note 59 at 15272.727272727261 with velocity 96
# rendering note 50 at 15272.727272727261 with velocity 96
# rendering note 64 at 15545.454545454533 with velocity 96
# rendering note 65 at 15681.81818181817 with velocity 96
# rendering note 67 at 15818.181818181805 with velocity 96
# rendering note 60 at 15818.181818181805 with velocity 96
# rendering note 48 at 15818.181818181805 with velocity 96
# rendering note 69 at 15954.545454545441 with velocity 96
# rendering note 71 at 16090.909090909077 with velocity 96
# rendering note 72 at 16227.272727272713 with velocity 96
# rendering note 74 at 16363.63636363635 with velocity 96
# rendering note 76 at 16499.999999999985 with velocity 96
# rendering note 74 at 16636.36363636362 with velocity 96
# rendering note 72 at 16772.727272727258 with velocity 96
# rendering note 71 at 16909.090909090894 with velocity 96
# rendering note 69 at 17045.45454545453 with velocity 96
# rendering note 67 at 17181.818181818166 with velocity 96
# rendering note 65 at 17318.1818181818 with velocity 96
# rendering note 64 at 17454.545454545438 with velocity 96
# rendering note 52 at 17454.545454545438 with velocity 96
# rendering note 48 at 17454.545454545438 with velocity 96
# rendering note 62 at 17727.27272727271 with velocity 96
# rendering note 64 at 17863.636363636346 with velocity 96
# rendering note 65 at 17999.99999999998 with velocity 96
# rendering note 67 at 18136.363636363618 with velocity 96
# rendering note 69 at 18272.727272727254 with velocity 96
# rendering note 71 at 18409.09090909089 with velocity 96
# rendering note 73 at 18545.454545454526 with velocity 96
# rendering note 74 at 18681.818181818162 with velocity 96
# rendering note 69 at 18818.181818181798 with velocity 96
# rendering note 71 at 18954.545454545434 with velocity 96
# rendering note 73 at 19090.90909090907 with velocity 96
# rendering note 74 at 19227.272727272706 with velocity 96
# rendering note 76 at 19363.636363636342 with velocity 96
# rendering note 77 at 19499.999999999978 with velocity 96
# rendering note 79 at 19636.363636363614 with velocity 96
# rendering note 57 at 19636.363636363614 with velocity 96
# rendering note 53 at 19636.363636363614 with velocity 96
# rendering note 81 at 19772.72727272725 with velocity 96
# rendering note 83 at 19909.090909090886 with velocity 96
# rendering note 84 at 20045.454545454522 with velocity 96
# rendering note 83 at 20181.81818181816 with velocity 96
# rendering note 81 at 20318.181818181794 with velocity 96
# rendering note 79 at 20454.54545454543 with velocity 96
# rendering note 53 at 20454.54545454543 with velocity 96
# rendering note 77 at 20590.909090909066 with velocity 96
# rendering note 76 at 20727.272727272702 with velocity 96
# rendering note 55 at 20727.272727272702 with velocity 96
# rendering note 77 at 20863.63636363634 with velocity 96
# rendering note 79 at 20999.999999999975 with velocity 96
# rendering note 81 at 21136.36363636361 with velocity 96
# rendering note 79 at 21272.727272727247 with velocity 96
# rendering note 57 at 21272.727272727247 with velocity 96
# rendering note 77 at 21409.090909090883 with velocity 96
# rendering note 76 at 21545.45454545452 with velocity 96
# rendering note 74 at 21681.818181818155 with velocity 96
# rendering note 72 at 21818.18181818179 with velocity 96
# rendering note 54 at 21818.18181818179 with velocity 96
# rendering note 43 at 21954.545454545427 with velocity 96
# rendering note 47 at 22090.909090909063 with velocity 96
# rendering note 71 at 22090.909090909063 with velocity 96
# rendering note 50 at 22227.2727272727 with velocity 96
# rendering note 55 at 22363.636363636335 with velocity 96
# rendering note 79 at 22363.636363636335 with velocity 96
# rendering note 43 at 22499.99999999997 with velocity 96
# rendering note 76 at 22568.18181818179 with velocity 96
# rendering note 48 at 22636.36363636361 with velocity 96
# rendering note 52 at 22772.727272727247 with velocity 96
# rendering note 72 at 22840.909090909066 with velocity 96
# rendering note 55 at 22909.090909090886 with velocity 96
# rendering note 43 at 23045.454545454522 with velocity 96
# rendering note 47 at 23181.81818181816 with velocity 96
# rendering note 74 at 23181.81818181816 with velocity 96
# rendering note 50 at 23318.181818181794 with velocity 96
# rendering note 55 at 23454.54545454543 with velocity 96
# rendering note 79 at 23454.54545454543 with velocity 96
# rendering note 43 at 23590.909090909066 with velocity 96
# rendering note 76 at 23659.090909090886 with velocity 96
# rendering note 48 at 23727.272727272706 with velocity 96
# rendering note 52 at 23863.636363636342 with velocity 96
# rendering note 72 at 23931.818181818162 with velocity 96
# rendering note 55 at 23999.99999999998 with velocity 96
# rendering note 74 at 24436.363636363618 with velocity 96
# rendering note 43 at 24436.363636363618 with velocity 96
# rendering note 71 at 24981.818181818162 with velocity 96
# rendering note 55 at 24981.818181818162 with velocity 96
# rendering note 79 at 24981.818181818162 with velocity 96
# rendering note 74 at 24981.818181818162 with velocity 96
# rendering note 67 at 25527.272727272706 with velocity 96
# rendering note 43 at 25527.272727272706 with velocity 96
# rendering note 61 at 26318.181818181798 with velocity 96
# rendering note 62 at 26454.545454545434 with velocity 96
# rendering note 61 at 26590.90909090907 with velocity 96
# rendering note 62 at 26727.272727272706 with velocity 96
# rendering note 61 at 26863.636363636342 with velocity 96
# rendering note 62 at 26999.999999999978 with velocity 96
# rendering note 61 at 27136.363636363614 with velocity 96
# rendering note 62 at 27272.72727272725 with velocity 96
# rendering note 60 at 27409.090909090886 with velocity 96
# rendering note 62 at 27545.454545454522 with velocity 96
# rendering note 60 at 27681.81818181816 with velocity 96
# rendering note 62 at 27818.181818181794 with velocity 96
# rendering note 60 at 27954.54545454543 with velocity 96
# rendering note 62 at 28090.909090909066 with velocity 96
# rendering note 60 at 28227.272727272702 with velocity 96
# rendering note 62 at 28363.63636363634 with velocity 96
# rendering note 59 at 28499.999999999975 with velocity 96
# rendering note 62 at 28636.36363636361 with velocity 96
# rendering note 86 at 28636.36363636361 with velocity 96
# rendering note 59 at 28772.727272727247 with velocity 96
# rendering note 62 at 28909.090909090883 with velocity 96
# rendering note 83 at 28909.090909090883 with velocity 96
# rendering note 59 at 29045.45454545452 with velocity 96
# rendering note 62 at 29181.818181818155 with velocity 96
# rendering note 59 at 29318.18181818179 with velocity 96
# rendering note 62 at 29454.545454545427 with velocity 96
# rendering note 59 at 29590.909090909063 with velocity 96
# rendering note 62 at 29727.2727272727 with velocity 96
# rendering note 79 at 29727.2727272727 with velocity 96
# rendering note 59 at 29863.636363636335 with velocity 96
# rendering note 81 at 29863.636363636335 with velocity 96
# rendering note 62 at 29999.99999999997 with velocity 96
# rendering note 83 at 29999.99999999997 with velocity 96
# rendering note 59 at 30136.363636363607 with velocity 96
# rendering note 62 at 30272.727272727243 with velocity 96
# rendering note 81 at 30272.727272727243 with velocity 96
# rendering note 59 at 30409.09090909088 with velocity 96
# rendering note 62 at 30545.454545454515 with velocity 96
# rendering note 79 at 30545.454545454515 with velocity 96
# rendering note 81 at 30613.636363636335 with velocity 96
# rendering note 79 at 30681.818181818155 with velocity 72
# rendering note 60 at 30681.818181818155 with velocity 96
# rendering note 81 at 30749.999999999975 with velocity 78
# rendering note 79 at 30818.181818181794 with velocity 84
# rendering note 62 at 30818.181818181794 with velocity 96
# rendering note 81 at 30886.363636363614 with velocity 90
# rendering note 79 at 30954.545454545434 with velocity 96
# rendering note 59 at 30954.545454545434 with velocity 96
# rendering note 78 at 31068.181818181798 with velocity 102
# rendering note 62 at 31090.90909090907 with velocity 96
# rendering note 57 at 31227.272727272706 with velocity 96
# rendering note 62 at 31363.636363636342 with velocity 96
# rendering note 59 at 31499.999999999978 with velocity 96
# rendering note 62 at 31636.363636363614 with velocity 96
# rendering note 78 at 31636.363636363614 with velocity 96
# rendering note 60 at 31772.72727272725 with velocity 96
# rendering note 62 at 31909.090909090886 with velocity 96
# rendering note 59 at 32045.454545454522 with velocity 96
# rendering note 62 at 32181.81818181816 with velocity 96
# rendering note 60 at 32318.181818181794 with velocity 96
# rendering note 62 at 32454.54545454543 with velocity 96
# rendering note 57 at 32590.909090909066 with velocity 96
# rendering note 62 at 32727.272727272702 with velocity 96
# rendering note 59 at 32863.63636363634 with velocity 96
# rendering note 62 at 32999.99999999998 with velocity 96
# rendering note 86 at 32999.99999999998 with velocity 96
# rendering note 59 at 33136.36363636362 with velocity 96
# rendering note 62 at 33272.72727272726 with velocity 96
# rendering note 83 at 33272.72727272726 with velocity 96
# rendering note 59 at 33409.0909090909 with velocity 96
# rendering note 62 at 33545.45454545454 with velocity 96
# rendering note 59 at 33681.81818181818 with velocity 96
# rendering note 62 at 33818.181818181816 with velocity 96
# rendering note 59 at 33954.545454545456 with velocity 96
# rendering note 62 at 34090.909090909096 with velocity 96
# rendering note 79 at 34090.909090909096 with velocity 96
# rendering note 59 at 34227.272727272735 with velocity 96
# rendering note 81 at 34227.272727272735 with velocity 96
# rendering note 62 at 34363.636363636375 with velocity 96
# rendering note 83 at 34363.636363636375 with velocity 96
# rendering note 59 at 34500.000000000015 with velocity 96
# rendering note 62 at 34636.363636363654 with velocity 96
# rendering note 81 at 34636.363636363654 with velocity 96
# rendering note 59 at 34772.727272727294 with velocity 96
# rendering note 62 at 34909.09090909093 with velocity 96
# rendering note 79 at 34909.09090909093 with velocity 96
# rendering note 81 at 34977.27272727275 with velocity 96
# rendering note 79 at 35045.454545454566 with velocity 72
# rendering note 60 at 35045.454545454566 with velocity 96
# rendering note 81 at 35113.63636363638 with velocity 78
# rendering note 79 at 35181.8181818182 with velocity 84
# rendering note 62 at 35181.8181818182 with velocity 96
# rendering note 81 at 35250.000000000015 with velocity 88
# rendering note 79 at 35318.18181818183 with velocity 94
# rendering note 59 at 35318.18181818183 with velocity 96
# rendering note 78 at 35431.81818181819 with velocity 102
# rendering note 62 at 35454.54545454546 with velocity 96
# rendering note 57 at 35590.9090909091 with velocity 96
# rendering note 62 at 35727.27272727274 with velocity 96
# rendering note 59 at 35863.63636363638 with velocity 96
# rendering note 62 at 36000.00000000002 with velocity 96
# rendering note 78 at 36000.00000000002 with velocity 96
# rendering note 60 at 36136.36363636366 with velocity 96
# rendering note 62 at 36272.7272727273 with velocity 96
# rendering note 59 at 36409.09090909094 with velocity 96
# rendering note 62 at 36545.45454545458 with velocity 96
# rendering note 60 at 36681.81818181822 with velocity 96
# rendering note 62 at 36818.18181818186 with velocity 96
# rendering note 57 at 36954.5454545455 with velocity 96
# rendering note 62 at 37090.90909090914 with velocity 96
# rendering note 59 at 37363.63636363642 with velocity 96
# rendering note 62 at 37500.00000000006 with velocity 96
# rendering note 67 at 37636.3636363637 with velocity 96
# rendering note 86 at 37636.3636363637 with velocity 96
# rendering note 86 at 37909.09090909098 with velocity 96
# rendering note 83 at 38045.45454545462 with velocity 96
# rendering note 79 at 38181.81818181826 with velocity 96
# rendering note 71 at 38181.81818181826 with velocity 96
# rendering note 60 at 38454.545454545536 with velocity 96
# rendering note 64 at 38590.909090909176 with velocity 96
# rendering note 67 at 38727.272727272815 with velocity 96
# rendering note 76 at 38727.272727272815 with velocity 96
# rendering note 76 at 39000.000000000095 with velocity 96
# rendering note 79 at 39136.363636363734 with velocity 96
# rendering note 76 at 39272.727272727374 with velocity 96
# rendering note 72 at 39272.727272727374 with velocity 96
# rendering note 57 at 39545.45454545465 with velocity 96
# rendering note 60 at 39681.81818181829 with velocity 96
# rendering note 66 at 39818.18181818193 with velocity 96
# rendering note 84 at 39818.18181818193 with velocity 96
# rendering note 84 at 40090.90909090921 with velocity 96
# rendering note 81 at 40227.27272727285 with velocity 96
# rendering note 78 at 40363.63636363649 with velocity 96
# rendering note 69 at 40363.63636363649 with velocity 96
# rendering note 59 at 40636.36363636377 with velocity 96
# rendering note 62 at 40772.72727272741 with velocity 96
# rendering note 66 at 40909.09090909105 with velocity 96
# rendering note 74 at 40909.09090909105 with velocity 96
# rendering note 74 at 41181.81818181833 with velocity 96
# rendering note 78 at 41318.18181818197 with velocity 96
# rendering note 74 at 41454.54545454561 with velocity 96
# rendering note 71 at 41454.54545454561 with velocity 96
# rendering note 55 at 41727.27272727289 with velocity 96
# rendering note 59 at 41863.63636363653 with velocity 96
# rendering note 64 at 42000.00000000017 with velocity 96
# rendering note 83 at 42000.00000000017 with velocity 96
# rendering note 83 at 42272.72727272745 with velocity 96
# rendering note 79 at 42409.090909091086 with velocity 96
# rendering note 76 at 42545.454545454726 with velocity 96
# rendering note 67 at 42545.454545454726 with velocity 96
# rendering note 57 at 42818.181818182005 with velocity 96
# rendering note 60 at 42954.545454545645 with velocity 96
# rendering note 64 at 43090.909090909285 with velocity 96
# rendering note 72 at 43090.909090909285 with velocity 96
# rendering note 72 at 43363.636363636564 with velocity 96
# rendering note 76 at 43500.000000000204 with velocity 96
# rendering note 72 at 43636.36363636384 with velocity 96
# rendering note 69 at 43636.36363636384 with velocity 96
# rendering note 54 at 43909.09090909112 with velocity 96
# rendering note 57 at 44045.45454545476 with velocity 96
# rendering note 62 at 44181.8181818184 with velocity 96
# rendering note 81 at 44181.8181818184 with velocity 96
# rendering note 81 at 44454.54545454568 with velocity 96
# rendering note 78 at 44590.90909090932 with velocity 96
# rendering note 74 at 44727.27272727296 with velocity 96
# rendering note 66 at 44727.27272727296 with velocity 96
# rendering note 55 at 45000.00000000024 with velocity 96
# rendering note 59 at 45136.36363636388 with velocity 96
# rendering note 62 at 45272.72727272752 with velocity 96
# rendering note 71 at 45272.72727272752 with velocity 96
# rendering note 79 at 45545.4545454548 with velocity 96
# rendering note 74 at 45681.81818181844 with velocity 96
# rendering note 71 at 45818.18181818208 with velocity 96
# rendering note 67 at 45818.18181818208 with velocity 96
# rendering note 60 at 46036.363636363894 with velocity 96
# rendering note 64 at 46036.363636363894 with velocity 96
# rendering note 60 at 46309.09090909117 with velocity 96
# rendering note 64 at 46309.09090909117 with velocity 96
# rendering note 60 at 46581.81818181844 with velocity 96
# rendering note 64 at 46581.81818181844 with velocity 96
# rendering note 60 at 46854.54545454571 with velocity 96
# rendering note 64 at 46854.54545454571 with velocity 96
# rendering note 69 at 46909.09090909117 with velocity 96
# rendering note 71 at 46977.27272727298 with velocity 108
# rendering note 60 at 47127.27272727298 with velocity 96
# rendering note 64 at 47127.27272727298 with velocity 96
# rendering note 60 at 47400.000000000255 with velocity 96
# rendering note 64 at 47400.000000000255 with velocity 96
# rendering note 72 at 47454.54545454571 with velocity 96
# rendering note 75 at 47522.72727272753 with velocity 108
# rendering note 60 at 47672.72727272753 with velocity 96
# rendering note 64 at 47672.72727272753 with velocity 96
# rendering note 64 at 47945.4545454548 with velocity 96
# rendering note 60 at 47945.4545454548 with velocity 96
# rendering note 76 at 48000.000000000255 with velocity 96
# rendering note 80 at 48068.18181818207 with velocity 108
# rendering note 60 at 48218.18181818207 with velocity 96
# rendering note 64 at 48218.18181818207 with velocity 96
# rendering note 60 at 48490.90909090934 with velocity 96
# rendering note 64 at 48490.90909090934 with velocity 96
# rendering note 60 at 48763.636363636615 with velocity 96
# rendering note 64 at 48763.636363636615 with velocity 96
# rendering note 81 at 48818.18181818207 with velocity 96
# rendering note 83 at 48886.36363636389 with velocity 96
# rendering note 81 at 48954.5454545457 with velocity 96
# rendering note 80 at 49022.72727272752 with velocity 96
# rendering note 60 at 49036.36363636388 with velocity 96
# rendering note 64 at 49036.36363636388 with velocity 96
# rendering note 81 at 49090.909090909336 with velocity 96
# rendering note 60 at 49309.09090909115 with velocity 96
# rendering note 64 at 49309.09090909115 with velocity 96
# rendering note 84 at 49363.63636363661 with velocity 96
# rendering note 60 at 49581.818181818424 with velocity 96
# rendering note 64 at 49581.818181818424 with velocity 96
# rendering note 81 at 49636.36363636388 with velocity 96
# rendering note 60 at 49854.545454545696 with velocity 96
# rendering note 64 at 49854.545454545696 with velocity 96
# rendering note 84 at 49909.09090909115 with velocity 96
# rendering note 64 at 50127.27272727297 with velocity 96
# rendering note 60 at 50127.27272727297 with velocity 96
# rendering note 81 at 50181.818181818424 with velocity 96
# rendering note 62 at 50318.18181818206 with velocity 96
# rendering note 71 at 50454.5454545457 with velocity 96
# rendering note 83 at 50454.5454545457 with velocity 96
# rendering note 67 at 50590.90909090934 with velocity 96
# rendering note 71 at 50727.27272727298 with velocity 96
# rendering note 79 at 50727.27272727298 with velocity 96
# rendering note 62 at 50863.63636363662 with velocity 96
# rendering note 71 at 51000.00000000026 with velocity 96
# rendering note 67 at 51136.3636363639 with velocity 96
# rendering note 71 at 51272.72727272754 with velocity 96
# rendering note 62 at 51409.09090909118 with velocity 96
# rendering note 71 at 51545.45454545482 with velocity 96
# rendering note 67 at 51681.81818181846 with velocity 96
# rendering note 71 at 51818.1818181821 with velocity 96
# rendering note 86 at 51818.1818181821 with velocity 96
# rendering note 62 at 51954.54545454574 with velocity 96
# rendering note 84 at 51954.54545454574 with velocity 96
# rendering note 71 at 52090.90909090938 with velocity 96
# rendering note 83 at 52090.90909090938 with velocity 96
# rendering note 67 at 52227.27272727302 with velocity 96
# rendering note 81 at 52227.27272727302 with velocity 96
# rendering note 71 at 52363.63636363666 with velocity 96
# rendering note 79 at 52363.63636363666 with velocity 96
# rendering note 83 at 52431.818181818475 with velocity 96
# rendering note 62 at 52500.00000000029 with velocity 96
# rendering note 81 at 52506.818181818475 with velocity 72
# rendering note 83 at 52575.0000000003 with velocity 72
# rendering note 81 at 52643.18181818212 with velocity 73
# rendering note 72 at 52650.000000000306 with velocity 72
# rendering note 83 at 52711.363636363945 with velocity 73
# rendering note 81 at 52779.54545454577 with velocity 75
# rendering note 66 at 52786.36363636395 with velocity 73
# rendering note 83 at 52847.72727272759 with velocity 75
# rendering note 81 at 52915.909090909416 with velocity 76
# rendering note 72 at 52922.7272727276 with velocity 75
# rendering note 83 at 52984.09090909124 with velocity 78
# rendering note 81 at 53052.27272727306 with velocity 78
# rendering note 62 at 53059.09090909125 with velocity 78
# rendering note 83 at 53120.454545454886 with velocity 79
# rendering note 81 at 53188.63636363671 with velocity 79
# rendering note 72 at 53195.45454545489 with velocity 79
# rendering note 83 at 53256.81818181853 with velocity 81
# rendering note 81 at 53325.00000000036 with velocity 81
# rendering note 66 at 53331.81818181854 with velocity 81
# rendering note 83 at 53393.18181818218 with velocity 82
# rendering note 81 at 53461.363636364 with velocity 84
# rendering note 72 at 53468.18181818219 with velocity 82
# rendering note 83 at 53529.54545454583 with velocity 84
# rendering note 81 at 53597.72727272765 with velocity 85
# rendering note 62 at 53604.545454545834 with velocity 84
# rendering note 83 at 53665.909090909474 with velocity 85
# rendering note 81 at 53734.0909090913 with velocity 87
# rendering note 72 at 53740.90909090948 with velocity 85
# rendering note 83 at 53802.27272727312 with velocity 87
# rendering note 81 at 53870.454545454944 with velocity 88
# rendering note 66 at 53877.27272727313 with velocity 87
# rendering note 83 at 53938.63636363677 with velocity 88
# rendering note 81 at 54006.81818181859 with velocity 90
# rendering note 72 at 54013.636363636775 with velocity 88
# rendering note 83 at 54075.000000000415 with velocity 91
# rendering note 81 at 54143.18181818224 with velocity 91
# rendering note 62 at 54150.00000000042 with velocity 91
# rendering note 83 at 54211.36363636406 with velocity 93
# rendering note 81 at 54279.545454545885 with velocity 93
# rendering note 72 at 54286.36363636407 with velocity 93
# rendering note 83 at 54347.72727272771 with velocity 94
# rendering note 81 at 54415.90909090953 with velocity 94
# rendering note 66 at 54422.727272727716 with velocity 94
# rendering note 79 at 54477.27272727317 with velocity 96
# rendering note 81 at 54545.45454545499 with velocity 96
# rendering note 72 at 54545.45454545499 with velocity 96
# rendering note 71 at 55090.90909090953 with velocity 96
# rendering note 67 at 55090.90909090953 with velocity 96
# rendering note 79 at 55090.90909090953 with velocity 96
# rendering note 79 at 55227.27272727317 with velocity 96
# rendering note 74 at 55363.63636363681 with velocity 96
# rendering note 79 at 55500.00000000045 with velocity 96
# rendering note 83 at 55636.36363636409 with velocity 96
# rendering note 86 at 55772.72727272773 with velocity 96
# rendering note 83 at 55909.09090909137 with velocity 96
# rendering note 79 at 56045.45454545501 with velocity 96
# rendering note 83 at 56181.81818181865 with velocity 96
# rendering note 84 at 56318.18181818229 with velocity 96
# rendering note 81 at 56454.54545454593 with velocity 96
# rendering note 78 at 56590.90909090957 with velocity 96
# rendering note 81 at 56727.27272727321 with velocity 96
# rendering note 72 at 56727.27272727321 with velocity 96
# rendering note 69 at 56727.27272727321 with velocity 96
# rendering note 62 at 56727.27272727321 with velocity 96
# rendering note 71 at 57272.72727272775 with velocity 96
# rendering note 79 at 57272.72727272775 with velocity 96
# rendering note 67 at 57272.72727272775 with velocity 96
# rendering note 67 at 57409.09090909139 with velocity 96
# rendering note 62 at 57545.45454545503 with velocity 96
# rendering note 67 at 57681.81818181867 with velocity 96
# rendering note 71 at 57818.18181818231 with velocity 96
# rendering note 74 at 57954.54545454595 with velocity 96
# rendering note 71 at 58090.90909090959 with velocity 96
# rendering note 67 at 58227.27272727323 with velocity 96
# rendering note 71 at 58363.63636363687 with velocity 96
# rendering note 72 at 58500.00000000051 with velocity 96
# rendering note 69 at 58636.36363636415 with velocity 96
# rendering note 66 at 58772.72727272779 with velocity 96
# rendering note 69 at 58909.09090909143 with velocity 96
# rendering note 60 at 58909.09090909143 with velocity 96
# rendering note 57 at 58909.09090909143 with velocity 96
# rendering note 50 at 58909.09090909143 with velocity 96
# rendering note 67 at 59345.45454545507 with velocity 96
# rendering note 55 at 59345.45454545507 with velocity 96
# rendering note 59 at 59345.45454545507 with velocity 96
# rendering note 74 at 59890.90909090962 with velocity 96
# rendering note 55 at 59890.90909090962 with velocity 96
# rendering note 43 at 59890.90909090962 with velocity 96
# rendering note 83 at 59890.90909090962 with velocity 96
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
